# %%
import pandas as pd
import numpy as np

# %%
##Load le fichier excel des réponses
data = pd.read_excel("FFQ.xlsx")
data
# Out:
#     CID                                               Q1_1  \
# 0   CID  1) Lait et produit laitiers - Lait entier (0.2...
# 1   066                                        1x par Sem.
# 2   074                                  Jamais ou <1/Mois
# 3   061                                      1-3x par Mois
# 4   092                                  Jamais ou <1/Mois
# ..  ...                                                ...
# 74  024                                        1x par Jour
# 75  097                                        1x par Sem.
# 76  094                                  Jamais ou <1/Mois
# 77  004                                  Jamais ou <1/Mois
# 78  073                                      2-4x par Sem.
#
#                                                  Q1_2  \
# 0   1) Lait et produit laitiers - Lait écrémé (0.2...
# 1                                         1x par Sem.
# 2                                   Jamais ou <1/Mois
# 3                                   Jamais ou <1/Mois
# 4                                         1x par Sem.
# ..                                                ...
# 74                                  Jamais ou <1/Mois
# 75                                      2-4x par Sem.
# 76                                  Jamais ou <1/Mois
# 77                                  Jamais ou <1/Mois
# 78                                  Jamais ou <1/Mois
#
#                                             Q1_3  \
# 0   1) Lait et produit laitiers - Yaourt (125 g)
# 1                                  2-4x par Sem.
# 2                                  1-3x par Mois
# 3                              Jamais ou <1/Mois
# 4                              Jamais ou <1/Mois
# ..                                           ...
# 74                                 1-3x par Mois
# 75                                 2-4x par Sem.
# 76                             Jamais ou <1/Mois
# 77                                   1x par Jour
# 78                                 5-6x par Sem.
#
#                                            Q1_4  \
# 0   1) Lait et produit laitiers - Quark (100 g)
# 1                                 2-4x par Sem.
# 2                             Jamais ou <1/Mois
# 3                             Jamais ou <1/Mois
# 4                             Jamais ou <1/Mois
# ..                                          ...
# 74                            Jamais ou <1/Mois
# 75                                2-4x par Sem.
# 76                            Jamais ou <1/Mois
# 77                            Jamais ou <1/Mois
# 78                            Jamais ou <1/Mois
#
#                                              Q1_5  \
# 0   1) Lait et produit laitiers - Fromage (100 g)
# 1                                   2-4x par Sem.
# 2                                     1x par Jour
# 3                                   2-4x par Sem.
# 4                               Jamais ou <1/Mois
# ..                                            ...
# 74                                  2-4x par Sem.
# 75                                  2-4x par Sem.
# 76                                  2-4x par Sem.
# 77                                  2-4x par Sem.
# 78                                  2-4x par Sem.
#
#                                           Q1_6  \
# 0   1) Lait et produit laitiers - Crème (20 g)
# 1                            Jamais ou <1/Mois
# 2                                2-4x par Sem.
# 3                            Jamais ou <1/Mois
# 4                            Jamais ou <1/Mois
# ..                                         ...
# 74                               1-3x par Mois
# 75                               2-4x par Sem.
# 76                               2-4x par Sem.
# 77                           Jamais ou <1/Mois
# 78                                 1x par Sem.
#
#                                         Q2_1  \
# 0   Fruits - Raisins ou raisins secs (100 g)
# 1                              2-4x par Sem.
# 2                              2-4x par Sem.
# 3                              2-4x par Sem.
# 4                              2-4x par Sem.
# ..                                       ...
# 74                         Jamais ou <1/Mois
# 75                         Jamais ou <1/Mois
# 76                             1-3x par Mois
# 77                             1-3x par Mois
# 78                         Jamais ou <1/Mois
#
#                                    Q2_2                                 Q2_3  \
# 0   Fruits - Pomme ou poire (1 portion)  Fruits - Pêche, abricot (1 portion)
# 1                         5-6x par Sem.                        1-3x par Mois
# 2                     Jamais ou <1/Mois                    Jamais ou <1/Mois
# 3                         1-3x par Mois                          1x par Sem.
# 4                           1x par Jour                        2-4x par Sem.
# ..                                  ...                                  ...
# 74                    Jamais ou <1/Mois                        2-4x par Sem.
# 75                          1x par Sem.                        2-4x par Sem.
# 76                        5-6x par Sem.                        2-4x par Sem.
# 77                        5-6x par Sem.                    Jamais ou <1/Mois
# 78                          1x par Sem.                        2-4x par Sem.
#
#     ...                                              Q23_3  \
# 0   ...  Par rapport aux vitamines de substitution: - P...
# 1   ...                                                NaN
# 2   ...                                                NaN
# 3   ...                                                NaN
# 4   ...                                                NaN
# ..  ...                                                ...
# 74  ...                                                NaN
# 75  ...                                                NaN
# 76  ...                                                NaN
# 77  ...                                                NaN
# 78  ...                                                NaN
#
#                                                 Q23_4  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                 Q23_5  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                 Q23_6  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                 Q23_7  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                 Q23_8  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                 Q23_9  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                Q23_10  \
# 0   Par rapport aux vitamines de substitution: - A...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                Q23_11  \
# 0   Par rapport aux vitamines de substitution: - V...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
#                                                Q23_12
# 0   Par rapport aux vitamines de substitution: - S...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
#
# [79 rows x 113 columns]

# %%
##Isoler les valeurs
answers = data.iloc[1:, 1:]
answers = answers.fillna(0)
answers = np.array(answers)

##Réponses différentes par question

#Trouver la question 9 (questions non-analysées après)
q9 = data.iloc[0].index.tolist().index('Q9') #nom de la colonne

#Questions 1-8
answers = data.iloc[1:, 1:q9]
answers = answers.fillna(0)
answers = np.array(answers)
answers_flat = answers.reshape(-1)
unique_answers1 = set()
for answer in answers_flat:
    unique_answers1.add(answer)
unique_answers1 = list(unique_answers1)
print(unique_answers1)

#Questions 9-23
#unique_answers2 = []
#for index in range(q9, answers.shape[1]):
    #unique_per_question = set()
    #for answer in answers[:,index]:
        #unique_per_question.add(answer)
    #unique_answers2.append(list(unique_per_question))
#print(unique_answers2)
# Out:
# ['5-6x par Sem.', '2-3x par Jour', '6x par Jour', '1x par Sem.', '2-4x par Sem.', '4-5x par Jour', '1-3x par Mois', 'Jamais ou <1/Mois', '1x par Jour']

# %%
#Valeurs numériques attribuées aux réponses : portions par semaine
dict_portions = { 0 : 0,
            '6x par Jour': 6*7, 
            '5-6x par Sem.' : 5.5, 
            '1x par Sem.' : 1, 
            '2-4x par Sem.' : 3,
            'Jamais ou <1/Mois' : 0,
            '2-3x par Jour' : 2.5*7,
            '4-5x par Jour' : 4.5*7, 
            '1-3x par Mois' : 2/4, 
            '1x par Jour' : 7 }

#Création d'un nouveau tableau avec les valeurs de portions par semaine
portions = []
for index in range(answers.shape[0]):
    portions_per_question = []
    for answer in answers[index,:]:
        portions_per_question.append(dict_portions[answer])
    portions.append(portions_per_question)
portions = np.array(portions)
portions #Lignes = personnes, Colonnes = questions
# Out:
# array([[1. , 1. , 3. , ..., 0.5, 0. , 0. ],
#        [0. , 0. , 0.5, ..., 0.5, 5.5, 0.5],
#        [0.5, 0. , 0. , ..., 1. , 3. , 0. ],
#        ...,
#        [0. , 0. , 0. , ..., 3. , 5.5, 1. ],
#        [0. , 0. , 7. , ..., 0. , 0. , 0. ],
#        [3. , 0. , 5.5, ..., 1. , 1. , 0. ]])

# %%
#Load le fichier excel des taux
data_cystein = pd.read_excel('taux.xlsx', sheet_name = "AFTER CONV")
data_cystein = data_cystein["Taux de cysteine [mg]"]
data_cystein
# Out:
# 0      62.50
# 1      80.00
# 2      33.75
# 3     112.00
# 4     136.00
#        ...
# 81      0.00
# 82     10.00
# 83     10.00
# 84     23.10
# 85      0.00
# Name: Taux de cysteine [mg], Length: 86, dtype: float64

# %%
cystein = np.array(data_cystein)
cystein = cystein.reshape(-1)

#Quantité totale de cystein par semaine par question en ug
total_per_question = portions * cystein

#Quantité totale de cystein par semaine en mg
total_per_week = total_per_question.sum(axis=1)

total_per_week
# Out:
# array([ 7353.945,  7672.185,  4335.6  ,  3875.4  ,  7627.485,  5349.235,
#         8963.235,  5923.885,  9747.125, 10637.2  ,  6831.075,  5451.855,
#         4455.12 ,  3569.375,  7652.69 , 10802.565,  9005.385, 14390.46 ,
#         7458.   ,  3225.41 ,  7169.825,  3110.8  ,  8417.125,  6211.79 ,
#         4319.775,  5083.535,  6189.835,  7698.   , 13668.565,  7800.26 ,
#         3948.845,  8522.385,  4775.02 ,  5541.02 ,  3005.735, 10315.885,
#        20429.175,  6587.05 ,  2597.6  ,  6508.27 ,  4887.55 ,  6279.3  ,
#         7156.675,  7843.895,  6788.265,  6176.885,  2197.85 ,  9425.125,
#         3505.485,  4885.235,  4716.015,  3653.855,  9308.31 ,  7796.135,
#         4033.785,  5510.035, 10735.475,  4730.785,  3919.185,  8232.8  ,
#         6126.21 ,  3424.42 ,  2360.835,  6612.315,  3970.7  ,  6831.36 ,
#         5915.915,  3191.02 ,  2491.15 ,  6689.285,  6354.535,  2396.175,
#         5733.56 ,  5630.32 ,  5751.62 ,  8281.035,  5348.475,  6368.11 ])

# %%
cid_to_cystein = {'CID': data.CID[1:], 'Cysteine par semaine [mg]': total_per_week}
df_cid_to_cystein = pd.DataFrame(data = cid_to_cystein).set_index('CID')
df_cid_to_cystein
# Out:
#      Cysteine par semaine [mg]
# CID
# 066                   7353.945
# 074                   7672.185
# 061                   4335.600
# 092                   3875.400
# 002                   7627.485
# ..                         ...
# 024                   5630.320
# 097                   5751.620
# 094                   8281.035
# 004                   5348.475
# 073                   6368.110
#
# [78 rows x 1 columns]

# %%
#Convert file to excel
df_cid_to_cystein.to_excel('Cystein_scoring.xlsx')
